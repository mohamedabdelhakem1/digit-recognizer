# %%
import  tensorflow as tf
import pandas as pd 
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

num_epoch = 10
dropout = 0.5
batch_size = 256
number_of_train_examples = 42000
steps = int (number_of_train_examples/batch_size)
number_of_test_examples = 28000
test_steps = int(number_of_test_examples /batch_size)
 # load and  preprocess training examples
def read_training_data(start ,end):    
    df = pd.read_csv('train.csv',skiprows = start , nrows = end - start)
    train_x_y = df.to_numpy()
    train_x = train_x_y[:,1:]
    train_y = train_x_y[:,0].reshape([train_x_y.shape[0] ,1])
    train_y = np.eye(10)[train_y] 
    train_y = train_y.reshape( [train_y.shape[0] ,train_y.shape[2]])
    train_x = train_x.reshape([train_x.shape[0],28,28,1])
    train_x = train_x /255.0
    return train_x , train_y

# load and preprocess test examples
def read_test_data(start , end):
    df = pd.read_csv('test.csv',skiprows = start , nrows = end - start)
    test_x = df.to_numpy()
    test_x = test_x.reshape([test_x.shape[0],28,28,1])
    test_x = test_x /255.0
    return test_x

# for i in range(0,100) :
#     x_sample = train_x[i,:,:,:].reshape((28,28)).astype('uint8')
#     im = Image.fromarray(x_sample)
#     im.save("images/"+ str(i) + ".jpeg")

X = tf.placeholder(dtype = tf.float32, shape=[None,28,28,1])
Y = tf.placeholder(dtype = tf.float32, shape=[None,10])
keep_prob = tf.placeholder(tf.float32)

def conv2d(x, w, b, strides=1):
    out = tf.nn.conv2d(x, w, strides=[1, strides, strides, 1], padding='SAME')
    out = out+ b
    return tf.nn.relu(out)

def max_pooling(x, k):
     return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1] , padding='SAME')

def model(x,keep_prob,Weights,Bias):
    
    # first convolution layer
    conv1  = conv2d(x ,Weights["w_conv1"] ,Bias["b_conv1"], 1)
    conv1  = max_pooling(conv1,2)
    
    # second convolution layer
    conv2  = conv2d(conv1 ,Weights["w_conv2"] ,Bias["b_conv2"], 1)
    conv2  = max_pooling(conv2,2)
    
    # first  fully connected layer
    fully1 = tf.reshape(conv2,shape  = [-1 ,7*7*64 ] )  
    fully1 = tf.nn.relu( tf.add( tf.matmul(fully1 , Weights['w_fc1']) ,Bias['b_fc1']))
    fully1 = tf.nn.dropout(fully1 , keep_prob)    
    # second  fully connected layer
    fully2 = tf.nn.relu( tf.add( tf.matmul(fully1 , Weights['w_fc2']) ,Bias['b_fc2']))
    fully2 = tf.nn.dropout(fully2 , keep_prob)    
    
   #softmax layer
    logits = tf.add(tf.matmul(fully2  , Weights['w_soft']) ,Bias['b_soft'])
    return logits

Weights = {
        "w_conv1" :tf.Variable (tf.truncated_normal(shape=[5,5,1,32] , stddev = 0.1 )),
        "w_conv2" :tf.Variable (tf.truncated_normal(shape=[5,5,32,64] , stddev = 0.1 )),
        "w_fc1" :tf.Variable ( tf.truncated_normal(shape=[7*7*64,1024] , stddev = 0.1)),
        "w_fc2" :tf.Variable ( tf.truncated_normal(shape=[1024,512] , stddev = 0.1)),
        "w_soft" :tf.Variable ( tf.truncated_normal(shape=[512,10] , stddev = 0.1 )),
       }
    
bias = {
        "b_conv1" :tf.Variable ( tf.constant(0.1,shape=[32] )),
        "b_conv2" :tf.Variable ( tf.constant(0.1,shape=[64] )),
        "b_fc1" :tf.Variable ( tf.constant( 0.1,shape=[1024] )),
        "b_fc2" :tf.Variable ( tf.constant( 0.1,shape=[512] )),
        "b_soft" :tf.Variable ( tf.constant(0.1,shape=[10] ))
        }
    

out  = model(X,keep_prob,Weights,bias)

cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = Y , logits = out ))

optimizer = tf.train.AdamOptimizer(learning_rate = 0.001)
train = optimizer.minimize(cost)

correct_prediction = tf.equal(tf.argmax(out, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
init = tf.global_variables_initializer()
saver = tf.train.Saver()
save_path = 'checkpoints/best_validation'

with tf.Session() as sess:
    sess.run(init)
    #training
    for j in range(0,num_epoch):
        total_epoch_acc = 0
        print("epoch" + str(j))
        for i in range(0,steps+1):
            start = i*batch_size
            end = (i+1)*batch_size
            batch_x ,batch_y =  read_training_data(start ,end)
            sess.run(train,feed_dict = {X :batch_x ,Y:batch_y , keep_prob : dropout})
            loss , acc =sess.run([cost,accuracy] ,feed_dict = {X :batch_x ,Y:batch_y , keep_prob :1.0})
            total_epoch_acc += acc
            print("Step " + str(i) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))
        print("total_epoch_acc " + str(total_epoch_acc / (steps+1)) )
        saver.save(sess, save_path)
    #testing
#     for i in range(0,test_steps+1):
#         start = i*batch_size
#         end = (i+1)*batch_size
#         batch_x  =  read_test_data(start ,end)
#         test_output =sess.run([out] ,feed_dict = {X :batch_x , keep_prob :1.0})
#         print(test_output)
# Out:
# epoch0
# Step 0, Minibatch Loss= 8.1610, Training Accuracy= 0.164
# Step 1, Minibatch Loss= 5.4458, Training Accuracy= 0.324
# Step 2, Minibatch Loss= 3.2506, Training Accuracy= 0.453
# Step 3, Minibatch Loss= 1.5727, Training Accuracy= 0.531
# Step 4, Minibatch Loss= 1.3391, Training Accuracy= 0.500
# Step 5, Minibatch Loss= 1.3957, Training Accuracy= 0.535
# Step 6, Minibatch Loss= 1.5510, Training Accuracy= 0.395
# Step 7, Minibatch Loss= 1.3514, Training Accuracy= 0.523
# Step 8, Minibatch Loss= 1.1755, Training Accuracy= 0.680
# Step 9, Minibatch Loss= 1.1687, Training Accuracy= 0.730
# Step 10, Minibatch Loss= 1.1641, Training Accuracy= 0.719
# Step 11, Minibatch Loss= 1.2551, Training Accuracy= 0.684
# Step 12, Minibatch Loss= 1.1870, Training Accuracy= 0.676
# Step 13, Minibatch Loss= 1.2147, Training Accuracy= 0.688
# Step 14, Minibatch Loss= 1.1304, Training Accuracy= 0.699
# Step 15, Minibatch Loss= 1.0527, Training Accuracy= 0.793
# Step 16, Minibatch Loss= 1.0584, Training Accuracy= 0.781
# Step 17, Minibatch Loss= 0.9596, Training Accuracy= 0.828
# Step 18, Minibatch Loss= 1.0202, Training Accuracy= 0.750
# Step 19, Minibatch Loss= 0.8980, Training Accuracy= 0.840
# Step 20, Minibatch Loss= 0.8633, Training Accuracy= 0.828
# Step 21, Minibatch Loss= 0.8682, Training Accuracy= 0.832
# Step 22, Minibatch Loss= 0.7013, Training Accuracy= 0.859
# Step 23, Minibatch Loss= 0.6371, Training Accuracy= 0.852
# Step 24, Minibatch Loss= 0.6063, Training Accuracy= 0.852
# Step 25, Minibatch Loss= 0.5632, Training Accuracy= 0.840
# Step 26, Minibatch Loss= 0.5354, Training Accuracy= 0.887
# Step 27, Minibatch Loss= 0.5080, Training Accuracy= 0.867
# Step 28, Minibatch Loss= 0.4393, Training Accuracy= 0.879
# Step 29, Minibatch Loss= 0.4950, Training Accuracy= 0.852
# Step 30, Minibatch Loss= 0.4141, Training Accuracy= 0.887
# Step 31, Minibatch Loss= 0.4082, Training Accuracy= 0.887
# Step 32, Minibatch Loss= 0.3529, Training Accuracy= 0.895
# Step 33, Minibatch Loss= 0.3080, Training Accuracy= 0.910
# Step 34, Minibatch Loss= 0.3375, Training Accuracy= 0.902
# Step 35, Minibatch Loss= 0.3729, Training Accuracy= 0.883
# Step 36, Minibatch Loss= 0.2486, Training Accuracy= 0.926
# Step 37, Minibatch Loss= 0.3178, Training Accuracy= 0.906
# Step 38, Minibatch Loss= 0.2655, Training Accuracy= 0.926
# Step 39, Minibatch Loss= 0.2319, Training Accuracy= 0.934
# Step 40, Minibatch Loss= 0.2779, Training Accuracy= 0.922
# Step 41, Minibatch Loss= 0.2648, Training Accuracy= 0.914
# Step 42, Minibatch Loss= 0.3731, Training Accuracy= 0.879
# Step 43, Minibatch Loss= 0.2388, Training Accuracy= 0.922
# Step 44, Minibatch Loss= 0.2853, Training Accuracy= 0.914
# Step 45, Minibatch Loss= 0.1849, Training Accuracy= 0.941
# Step 46, Minibatch Loss= 0.3213, Training Accuracy= 0.914
# Step 47, Minibatch Loss= 0.2061, Training Accuracy= 0.945
# Step 48, Minibatch Loss= 0.2607, Training Accuracy= 0.926
# Step 49, Minibatch Loss= 0.2271, Training Accuracy= 0.926
# Step 50, Minibatch Loss= 0.3737, Training Accuracy= 0.875
# Step 51, Minibatch Loss= 0.2752, Training Accuracy= 0.926
# Step 52, Minibatch Loss= 0.2704, Training Accuracy= 0.906
# Step 53, Minibatch Loss= 0.2088, Training Accuracy= 0.922
# Step 54, Minibatch Loss= 0.1883, Training Accuracy= 0.938
# Step 55, Minibatch Loss= 0.1834, Training Accuracy= 0.934
# Step 56, Minibatch Loss= 0.2766, Training Accuracy= 0.918
# Step 57, Minibatch Loss= 0.2083, Training Accuracy= 0.934
# Step 58, Minibatch Loss= 0.1627, Training Accuracy= 0.973
# Step 59, Minibatch Loss= 0.2235, Training Accuracy= 0.945
# Step 60, Minibatch Loss= 0.1381, Training Accuracy= 0.953
# Step 61, Minibatch Loss= 0.1444, Training Accuracy= 0.957
# Step 62, Minibatch Loss= 0.2081, Training Accuracy= 0.949
# Step 63, Minibatch Loss= 0.2181, Training Accuracy= 0.953
# Step 64, Minibatch Loss= 0.1725, Training Accuracy= 0.953
# Step 65, Minibatch Loss= 0.2114, Training Accuracy= 0.934
# Step 66, Minibatch Loss= 0.2219, Training Accuracy= 0.930
# Step 67, Minibatch Loss= 0.1321, Training Accuracy= 0.961
# Step 68, Minibatch Loss= 0.1624, Training Accuracy= 0.945
# Step 69, Minibatch Loss= 0.1344, Training Accuracy= 0.961
# Step 70, Minibatch Loss= 0.1147, Training Accuracy= 0.961
# Step 71, Minibatch Loss= 0.1880, Training Accuracy= 0.941
# Step 72, Minibatch Loss= 0.1671, Training Accuracy= 0.957
# Step 73, Minibatch Loss= 0.2205, Training Accuracy= 0.930
# Step 74, Minibatch Loss= 0.1774, Training Accuracy= 0.934
# Step 75, Minibatch Loss= 0.1355, Training Accuracy= 0.961
# Step 76, Minibatch Loss= 0.1410, Training Accuracy= 0.953
# Step 77, Minibatch Loss= 0.1290, Training Accuracy= 0.973
# Step 78, Minibatch Loss= 0.1836, Training Accuracy= 0.938
# Step 79, Minibatch Loss= 0.1062, Training Accuracy= 0.969
# Step 80, Minibatch Loss= 0.1602, Training Accuracy= 0.957
# Step 81, Minibatch Loss= 0.1805, Training Accuracy= 0.941
# Step 82, Minibatch Loss= 0.1183, Training Accuracy= 0.969
# Step 83, Minibatch Loss= 0.1899, Training Accuracy= 0.953
# Step 84, Minibatch Loss= 0.2455, Training Accuracy= 0.941
# Step 85, Minibatch Loss= 0.1881, Training Accuracy= 0.945
# Step 86, Minibatch Loss= 0.1164, Training Accuracy= 0.961
# Step 87, Minibatch Loss= 0.1562, Training Accuracy= 0.949
# Step 88, Minibatch Loss= 0.1535, Training Accuracy= 0.961
# Step 89, Minibatch Loss= 0.1285, Training Accuracy= 0.961
# Step 90, Minibatch Loss= 0.1616, Training Accuracy= 0.961
# Step 91, Minibatch Loss= 0.1533, Training Accuracy= 0.961
# Step 92, Minibatch Loss= 0.2152, Training Accuracy= 0.930
# Step 93, Minibatch Loss= 0.1689, Training Accuracy= 0.949
# Step 94, Minibatch Loss= 0.1671, Training Accuracy= 0.949
# Step 95, Minibatch Loss= 0.1313, Training Accuracy= 0.961
# Step 96, Minibatch Loss= 0.1726, Training Accuracy= 0.953
# Step 97, Minibatch Loss= 0.1894, Training Accuracy= 0.949
# Step 98, Minibatch Loss= 0.1632, Training Accuracy= 0.957
# Step 99, Minibatch Loss= 0.0785, Training Accuracy= 0.980
# Step 100, Minibatch Loss= 0.1548, Training Accuracy= 0.941
# Step 101, Minibatch Loss= 0.1640, Training Accuracy= 0.957
# Step 102, Minibatch Loss= 0.0897, Training Accuracy= 0.977
# Step 103, Minibatch Loss= 0.1616, Training Accuracy= 0.953
# Step 104, Minibatch Loss= 0.1329, Training Accuracy= 0.965
# Step 105, Minibatch Loss= 0.0950, Training Accuracy= 0.977
# Step 106, Minibatch Loss= 0.1369, Training Accuracy= 0.965
# Step 107, Minibatch Loss= 0.1471, Training Accuracy= 0.941
# Step 108, Minibatch Loss= 0.1800, Training Accuracy= 0.945
# Step 109, Minibatch Loss= 0.1232, Training Accuracy= 0.969
# Step 110, Minibatch Loss= 0.0947, Training Accuracy= 0.977
# Step 111, Minibatch Loss= 0.1228, Training Accuracy= 0.961
# Step 112, Minibatch Loss= 0.1854, Training Accuracy= 0.957
# Step 113, Minibatch Loss= 0.0882, Training Accuracy= 0.953
# Step 114, Minibatch Loss= 0.1339, Training Accuracy= 0.969
# Step 115, Minibatch Loss= 0.1363, Training Accuracy= 0.961
# Step 116, Minibatch Loss= 0.1258, Training Accuracy= 0.961
# Step 117, Minibatch Loss= 0.1297, Training Accuracy= 0.961
# Step 118, Minibatch Loss= 0.1818, Training Accuracy= 0.934
# Step 119, Minibatch Loss= 0.0905, Training Accuracy= 0.977
# Step 120, Minibatch Loss= 0.0863, Training Accuracy= 0.980
# Step 121, Minibatch Loss= 0.1209, Training Accuracy= 0.969
# Step 122, Minibatch Loss= 0.0904, Training Accuracy= 0.973
# Step 123, Minibatch Loss= 0.1507, Training Accuracy= 0.961
# Step 124, Minibatch Loss= 0.0902, Training Accuracy= 0.965
# Step 125, Minibatch Loss= 0.1195, Training Accuracy= 0.961
# Step 126, Minibatch Loss= 0.0564, Training Accuracy= 0.992
# Step 127, Minibatch Loss= 0.1517, Training Accuracy= 0.957
# Step 128, Minibatch Loss= 0.0749, Training Accuracy= 0.973
# Step 129, Minibatch Loss= 0.0936, Training Accuracy= 0.965
# Step 130, Minibatch Loss= 0.1556, Training Accuracy= 0.945
# Step 131, Minibatch Loss= 0.0949, Training Accuracy= 0.969
# Step 132, Minibatch Loss= 0.0717, Training Accuracy= 0.973
# Step 133, Minibatch Loss= 0.1406, Training Accuracy= 0.938
# Step 134, Minibatch Loss= 0.0568, Training Accuracy= 0.988
# Step 135, Minibatch Loss= 0.0761, Training Accuracy= 0.973
# Step 136, Minibatch Loss= 0.1123, Training Accuracy= 0.957
# Step 137, Minibatch Loss= 0.0755, Training Accuracy= 0.980
# Step 138, Minibatch Loss= 0.1174, Training Accuracy= 0.973
# Step 139, Minibatch Loss= 0.0862, Training Accuracy= 0.969
# Step 140, Minibatch Loss= 0.0584, Training Accuracy= 0.977
# Step 141, Minibatch Loss= 0.0625, Training Accuracy= 0.984
# Step 142, Minibatch Loss= 0.0509, Training Accuracy= 0.988
# Step 143, Minibatch Loss= 0.1089, Training Accuracy= 0.965
# Step 144, Minibatch Loss= 0.1358, Training Accuracy= 0.953
# Step 145, Minibatch Loss= 0.0918, Training Accuracy= 0.969
# Step 146, Minibatch Loss= 0.0806, Training Accuracy= 0.977
# Step 147, Minibatch Loss= 0.1284, Training Accuracy= 0.965
# Step 148, Minibatch Loss= 0.0922, Training Accuracy= 0.977
# Step 149, Minibatch Loss= 0.0648, Training Accuracy= 0.980
# Step 150, Minibatch Loss= 0.0789, Training Accuracy= 0.973
# Step 151, Minibatch Loss= 0.1277, Training Accuracy= 0.961
# Step 152, Minibatch Loss= 0.0903, Training Accuracy= 0.965
# Step 153, Minibatch Loss= 0.0976, Training Accuracy= 0.973
# Step 154, Minibatch Loss= 0.0644, Training Accuracy= 0.980
# Step 155, Minibatch Loss= 0.0780, Training Accuracy= 0.977
# Step 156, Minibatch Loss= 0.1060, Training Accuracy= 0.965
# Step 157, Minibatch Loss= 0.1368, Training Accuracy= 0.965
# Step 158, Minibatch Loss= 0.1320, Training Accuracy= 0.961
# Step 159, Minibatch Loss= 0.0987, Training Accuracy= 0.969
# Step 160, Minibatch Loss= 0.0973, Training Accuracy= 0.969
# Step 161, Minibatch Loss= 0.0901, Training Accuracy= 0.957
# Step 162, Minibatch Loss= 0.0702, Training Accuracy= 0.980
# Step 163, Minibatch Loss= 0.1201, Training Accuracy= 0.953
# Step 164, Minibatch Loss= 0.0049, Training Accuracy= 1.000
# total_epoch_acc 0.9049005681818182
# epoch1
# Step 0, Minibatch Loss= 0.0993, Training Accuracy= 0.969
# Step 1, Minibatch Loss= 0.0622, Training Accuracy= 0.973
# Step 2, Minibatch Loss= 0.1345, Training Accuracy= 0.973
# Step 3, Minibatch Loss= 0.0860, Training Accuracy= 0.984
# Step 4, Minibatch Loss= 0.0768, Training Accuracy= 0.977
# Step 5, Minibatch Loss= 0.0793, Training Accuracy= 0.977
# Step 6, Minibatch Loss= 0.0699, Training Accuracy= 0.980
# Step 7, Minibatch Loss= 0.0916, Training Accuracy= 0.977
# Step 8, Minibatch Loss= 0.1038, Training Accuracy= 0.969
# Step 9, Minibatch Loss= 0.0842, Training Accuracy= 0.977
# Step 10, Minibatch Loss= 0.0557, Training Accuracy= 0.984
# Step 11, Minibatch Loss= 0.1016, Training Accuracy= 0.965
# Step 12, Minibatch Loss= 0.0863, Training Accuracy= 0.969
# Step 13, Minibatch Loss= 0.0789, Training Accuracy= 0.984
# Step 14, Minibatch Loss= 0.0961, Training Accuracy= 0.977
# Step 15, Minibatch Loss= 0.1032, Training Accuracy= 0.973
# Step 16, Minibatch Loss= 0.0421, Training Accuracy= 0.992
# Step 17, Minibatch Loss= 0.0579, Training Accuracy= 0.980
# Step 18, Minibatch Loss= 0.0724, Training Accuracy= 0.984
# Step 19, Minibatch Loss= 0.1036, Training Accuracy= 0.965
# Step 20, Minibatch Loss= 0.0992, Training Accuracy= 0.969
# Step 21, Minibatch Loss= 0.1159, Training Accuracy= 0.965
# Step 22, Minibatch Loss= 0.1029, Training Accuracy= 0.961
# Step 23, Minibatch Loss= 0.0657, Training Accuracy= 0.984
# Step 24, Minibatch Loss= 0.0833, Training Accuracy= 0.969
# Step 25, Minibatch Loss= 0.0833, Training Accuracy= 0.969
# Step 26, Minibatch Loss= 0.0890, Training Accuracy= 0.969
# Step 27, Minibatch Loss= 0.0784, Training Accuracy= 0.965
# Step 28, Minibatch Loss= 0.0605, Training Accuracy= 0.965
# Step 29, Minibatch Loss= 0.1477, Training Accuracy= 0.949
# Step 30, Minibatch Loss= 0.0824, Training Accuracy= 0.969
# Step 31, Minibatch Loss= 0.0868, Training Accuracy= 0.965
# Step 32, Minibatch Loss= 0.0532, Training Accuracy= 0.984
# Step 33, Minibatch Loss= 0.0564, Training Accuracy= 0.980
# Step 34, Minibatch Loss= 0.0769, Training Accuracy= 0.980
# Step 35, Minibatch Loss= 0.0632, Training Accuracy= 0.973
# Step 36, Minibatch Loss= 0.0667, Training Accuracy= 0.988
# Step 37, Minibatch Loss= 0.0603, Training Accuracy= 0.980
# Step 38, Minibatch Loss= 0.0943, Training Accuracy= 0.973
# Step 39, Minibatch Loss= 0.0340, Training Accuracy= 0.992
# Step 40, Minibatch Loss= 0.0668, Training Accuracy= 0.973
# Step 41, Minibatch Loss= 0.0821, Training Accuracy= 0.973
# Step 42, Minibatch Loss= 0.1061, Training Accuracy= 0.957
# Step 43, Minibatch Loss= 0.0437, Training Accuracy= 0.988
# Step 44, Minibatch Loss= 0.0827, Training Accuracy= 0.969
# Step 45, Minibatch Loss= 0.0345, Training Accuracy= 0.996
# Step 46, Minibatch Loss= 0.0737, Training Accuracy= 0.977
# Step 47, Minibatch Loss= 0.0524, Training Accuracy= 0.984
# Step 48, Minibatch Loss= 0.0776, Training Accuracy= 0.977
# Step 49, Minibatch Loss= 0.0614, Training Accuracy= 0.977
# Step 50, Minibatch Loss= 0.1671, Training Accuracy= 0.953
# Step 51, Minibatch Loss= 0.0961, Training Accuracy= 0.965
# Step 52, Minibatch Loss= 0.0914, Training Accuracy= 0.969
# Step 53, Minibatch Loss= 0.0827, Training Accuracy= 0.977
# Step 54, Minibatch Loss= 0.0654, Training Accuracy= 0.973
# Step 55, Minibatch Loss= 0.0355, Training Accuracy= 0.992
# Step 56, Minibatch Loss= 0.1069, Training Accuracy= 0.965
# Step 57, Minibatch Loss= 0.0386, Training Accuracy= 0.988
# Step 58, Minibatch Loss= 0.0626, Training Accuracy= 0.984
# Step 59, Minibatch Loss= 0.0768, Training Accuracy= 0.984
# Step 60, Minibatch Loss= 0.0394, Training Accuracy= 0.992
# Step 61, Minibatch Loss= 0.0633, Training Accuracy= 0.977
# Step 62, Minibatch Loss= 0.0649, Training Accuracy= 0.973
# Step 63, Minibatch Loss= 0.1214, Training Accuracy= 0.984
# Step 64, Minibatch Loss= 0.0516, Training Accuracy= 0.988
# Step 65, Minibatch Loss= 0.0756, Training Accuracy= 0.973
# Step 66, Minibatch Loss= 0.0667, Training Accuracy= 0.977
# Step 67, Minibatch Loss= 0.0349, Training Accuracy= 0.988
# Step 68, Minibatch Loss= 0.0601, Training Accuracy= 0.980
# Step 69, Minibatch Loss= 0.0431, Training Accuracy= 0.984
# Step 70, Minibatch Loss= 0.0501, Training Accuracy= 0.988
# Step 71, Minibatch Loss= 0.1057, Training Accuracy= 0.969
# Step 72, Minibatch Loss= 0.0953, Training Accuracy= 0.969
# Step 73, Minibatch Loss= 0.0772, Training Accuracy= 0.969
# Step 74, Minibatch Loss= 0.0659, Training Accuracy= 0.984
# Step 75, Minibatch Loss= 0.0669, Training Accuracy= 0.969
# Step 76, Minibatch Loss= 0.0489, Training Accuracy= 0.980
# Step 77, Minibatch Loss= 0.0441, Training Accuracy= 0.992
# Step 78, Minibatch Loss= 0.0464, Training Accuracy= 0.977
# Step 79, Minibatch Loss= 0.0297, Training Accuracy= 0.988
# Step 80, Minibatch Loss= 0.0857, Training Accuracy= 0.969
# Step 81, Minibatch Loss= 0.0746, Training Accuracy= 0.980
# Step 82, Minibatch Loss= 0.0566, Training Accuracy= 0.980
# Step 83, Minibatch Loss= 0.0801, Training Accuracy= 0.977
# Step 84, Minibatch Loss= 0.1221, Training Accuracy= 0.957
# Step 85, Minibatch Loss= 0.0691, Training Accuracy= 0.977
# Step 86, Minibatch Loss= 0.0611, Training Accuracy= 0.973
# Step 87, Minibatch Loss= 0.0628, Training Accuracy= 0.980
# Step 88, Minibatch Loss= 0.0556, Training Accuracy= 0.980
# Step 89, Minibatch Loss= 0.0670, Training Accuracy= 0.977
# Step 90, Minibatch Loss= 0.0929, Training Accuracy= 0.969
# Step 91, Minibatch Loss= 0.0970, Training Accuracy= 0.977
# Step 92, Minibatch Loss= 0.0908, Training Accuracy= 0.973
# Step 93, Minibatch Loss= 0.0676, Training Accuracy= 0.973
# Step 94, Minibatch Loss= 0.0952, Training Accuracy= 0.969
# Step 95, Minibatch Loss= 0.0544, Training Accuracy= 0.977
# Step 96, Minibatch Loss= 0.1135, Training Accuracy= 0.973
# Step 97, Minibatch Loss= 0.1023, Training Accuracy= 0.965
# Step 98, Minibatch Loss= 0.0758, Training Accuracy= 0.973
# Step 99, Minibatch Loss= 0.0239, Training Accuracy= 0.996
# Step 100, Minibatch Loss= 0.0927, Training Accuracy= 0.977
# Step 101, Minibatch Loss= 0.0887, Training Accuracy= 0.973
# Step 102, Minibatch Loss= 0.0441, Training Accuracy= 0.988
# Step 103, Minibatch Loss= 0.0511, Training Accuracy= 0.984
# Step 104, Minibatch Loss= 0.0629, Training Accuracy= 0.984
# Step 105, Minibatch Loss= 0.0521, Training Accuracy= 0.984
# Step 106, Minibatch Loss= 0.0802, Training Accuracy= 0.977
# Step 107, Minibatch Loss= 0.0422, Training Accuracy= 0.980
# Step 108, Minibatch Loss= 0.0840, Training Accuracy= 0.984
# Step 109, Minibatch Loss= 0.0680, Training Accuracy= 0.984
# Step 110, Minibatch Loss= 0.0389, Training Accuracy= 0.988
# Step 111, Minibatch Loss= 0.0698, Training Accuracy= 0.980
# Step 112, Minibatch Loss= 0.0986, Training Accuracy= 0.977
# Step 113, Minibatch Loss= 0.0285, Training Accuracy= 0.992
# Step 114, Minibatch Loss= 0.0672, Training Accuracy= 0.977
# Step 115, Minibatch Loss= 0.0651, Training Accuracy= 0.973
# Step 116, Minibatch Loss= 0.0606, Training Accuracy= 0.980
# Step 117, Minibatch Loss= 0.0735, Training Accuracy= 0.984
# Step 118, Minibatch Loss= 0.0805, Training Accuracy= 0.973
# Step 119, Minibatch Loss= 0.0292, Training Accuracy= 0.984
# Step 120, Minibatch Loss= 0.0240, Training Accuracy= 0.996
# Step 121, Minibatch Loss= 0.0465, Training Accuracy= 0.988
# Step 122, Minibatch Loss= 0.0238, Training Accuracy= 0.992
# Step 123, Minibatch Loss= 0.0700, Training Accuracy= 0.977
# Step 124, Minibatch Loss= 0.0310, Training Accuracy= 0.996
# Step 125, Minibatch Loss= 0.0560, Training Accuracy= 0.973
# Step 126, Minibatch Loss= 0.0349, Training Accuracy= 0.992
# Step 127, Minibatch Loss= 0.0941, Training Accuracy= 0.973
# Step 128, Minibatch Loss= 0.0253, Training Accuracy= 0.992
# Step 129, Minibatch Loss= 0.0483, Training Accuracy= 0.984
# Step 130, Minibatch Loss= 0.0726, Training Accuracy= 0.984
# Step 131, Minibatch Loss= 0.0214, Training Accuracy= 0.996
# Step 132, Minibatch Loss= 0.0308, Training Accuracy= 0.988
# Step 133, Minibatch Loss= 0.0603, Training Accuracy= 0.984
# Step 134, Minibatch Loss= 0.0348, Training Accuracy= 0.988
# Step 135, Minibatch Loss= 0.0349, Training Accuracy= 0.984
# Step 136, Minibatch Loss= 0.0487, Training Accuracy= 0.977
# Step 137, Minibatch Loss= 0.0346, Training Accuracy= 0.984
# Step 138, Minibatch Loss= 0.0760, Training Accuracy= 0.969
# Step 139, Minibatch Loss= 0.0434, Training Accuracy= 0.984
# Step 140, Minibatch Loss= 0.0316, Training Accuracy= 0.988
# Step 141, Minibatch Loss= 0.0365, Training Accuracy= 0.992
# Step 142, Minibatch Loss= 0.0378, Training Accuracy= 0.980
# Step 143, Minibatch Loss= 0.0581, Training Accuracy= 0.980
# Step 144, Minibatch Loss= 0.0975, Training Accuracy= 0.973
# Step 145, Minibatch Loss= 0.0586, Training Accuracy= 0.984
# Step 146, Minibatch Loss= 0.0528, Training Accuracy= 0.988
# Step 147, Minibatch Loss= 0.0846, Training Accuracy= 0.977
# Step 148, Minibatch Loss= 0.0395, Training Accuracy= 0.984
# Step 149, Minibatch Loss= 0.0398, Training Accuracy= 0.992
# Step 150, Minibatch Loss= 0.0263, Training Accuracy= 0.992
# Step 151, Minibatch Loss= 0.0668, Training Accuracy= 0.984
# Step 152, Minibatch Loss= 0.0523, Training Accuracy= 0.980
# Step 153, Minibatch Loss= 0.0682, Training Accuracy= 0.977
# Step 154, Minibatch Loss= 0.0232, Training Accuracy= 0.992
# Step 155, Minibatch Loss= 0.0368, Training Accuracy= 0.988
# Step 156, Minibatch Loss= 0.0667, Training Accuracy= 0.973
# Step 157, Minibatch Loss= 0.0638, Training Accuracy= 0.973
# Step 158, Minibatch Loss= 0.0762, Training Accuracy= 0.977
# Step 159, Minibatch Loss= 0.0427, Training Accuracy= 0.992
# Step 160, Minibatch Loss= 0.0319, Training Accuracy= 0.988
# Step 161, Minibatch Loss= 0.0669, Training Accuracy= 0.980
# Step 162, Minibatch Loss= 0.0342, Training Accuracy= 0.992
# Step 163, Minibatch Loss= 0.0653, Training Accuracy= 0.973
# Step 164, Minibatch Loss= 0.0020, Training Accuracy= 1.000
# total_epoch_acc 0.97890625
# epoch2
# Step 0, Minibatch Loss= 0.0559, Training Accuracy= 0.977
# Step 1, Minibatch Loss= 0.0193, Training Accuracy= 0.996
# Step 2, Minibatch Loss= 0.0706, Training Accuracy= 0.984
# Step 3, Minibatch Loss= 0.0450, Training Accuracy= 0.988
# Step 4, Minibatch Loss= 0.0329, Training Accuracy= 0.996
# Step 5, Minibatch Loss= 0.0280, Training Accuracy= 0.988
# Step 6, Minibatch Loss= 0.0272, Training Accuracy= 0.984
# Step 7, Minibatch Loss= 0.0474, Training Accuracy= 0.988
# Step 8, Minibatch Loss= 0.0388, Training Accuracy= 0.984
# Step 9, Minibatch Loss= 0.0393, Training Accuracy= 0.980
# Step 10, Minibatch Loss= 0.0273, Training Accuracy= 0.996
# Step 11, Minibatch Loss= 0.0568, Training Accuracy= 0.984
# Step 12, Minibatch Loss= 0.0561, Training Accuracy= 0.980
# Step 13, Minibatch Loss= 0.0412, Training Accuracy= 0.984
# Step 14, Minibatch Loss= 0.0574, Training Accuracy= 0.988
# Step 15, Minibatch Loss= 0.0692, Training Accuracy= 0.977
# Step 16, Minibatch Loss= 0.0208, Training Accuracy= 0.992
# Step 17, Minibatch Loss= 0.0366, Training Accuracy= 0.988
# Step 18, Minibatch Loss= 0.0320, Training Accuracy= 0.992
# Step 19, Minibatch Loss= 0.0738, Training Accuracy= 0.977
# Step 20, Minibatch Loss= 0.0612, Training Accuracy= 0.984
# Step 21, Minibatch Loss= 0.0644, Training Accuracy= 0.984
# Step 22, Minibatch Loss= 0.0629, Training Accuracy= 0.984
# Step 23, Minibatch Loss= 0.0549, Training Accuracy= 0.984
# Step 24, Minibatch Loss= 0.0603, Training Accuracy= 0.977
# Step 25, Minibatch Loss= 0.0333, Training Accuracy= 0.988
# Step 26, Minibatch Loss= 0.0574, Training Accuracy= 0.984
# Step 27, Minibatch Loss= 0.0308, Training Accuracy= 0.988
# Step 28, Minibatch Loss= 0.0483, Training Accuracy= 0.988
# Step 29, Minibatch Loss= 0.1015, Training Accuracy= 0.965
# Step 30, Minibatch Loss= 0.0534, Training Accuracy= 0.980
# Step 31, Minibatch Loss= 0.0460, Training Accuracy= 0.980
# Step 32, Minibatch Loss= 0.0282, Training Accuracy= 0.992
# Step 33, Minibatch Loss= 0.0258, Training Accuracy= 0.992
# Step 34, Minibatch Loss= 0.0506, Training Accuracy= 0.980
# Step 35, Minibatch Loss= 0.0258, Training Accuracy= 0.996
# Step 36, Minibatch Loss= 0.0477, Training Accuracy= 0.992
# Step 37, Minibatch Loss= 0.0406, Training Accuracy= 0.988
# Step 38, Minibatch Loss= 0.0504, Training Accuracy= 0.984
# Step 39, Minibatch Loss= 0.0181, Training Accuracy= 0.996
# Step 40, Minibatch Loss= 0.0526, Training Accuracy= 0.988
# Step 41, Minibatch Loss= 0.0568, Training Accuracy= 0.988
# Step 42, Minibatch Loss= 0.0511, Training Accuracy= 0.977
# Step 43, Minibatch Loss= 0.0257, Training Accuracy= 0.996
# Step 44, Minibatch Loss= 0.0568, Training Accuracy= 0.980
# Step 45, Minibatch Loss= 0.0195, Training Accuracy= 0.996
# Step 46, Minibatch Loss= 0.0462, Training Accuracy= 0.992
# Step 47, Minibatch Loss= 0.0196, Training Accuracy= 1.000
# Step 48, Minibatch Loss= 0.0488, Training Accuracy= 0.988
# Step 49, Minibatch Loss= 0.0288, Training Accuracy= 0.988
# Step 50, Minibatch Loss= 0.1428, Training Accuracy= 0.961
# Step 51, Minibatch Loss= 0.0648, Training Accuracy= 0.977
# Step 52, Minibatch Loss= 0.0472, Training Accuracy= 0.984
# Step 53, Minibatch Loss= 0.0593, Training Accuracy= 0.980
# Step 54, Minibatch Loss= 0.0356, Training Accuracy= 0.988
# Step 55, Minibatch Loss= 0.0275, Training Accuracy= 0.988
# Step 56, Minibatch Loss= 0.0678, Training Accuracy= 0.980
# Step 57, Minibatch Loss= 0.0215, Training Accuracy= 0.992
# Step 58, Minibatch Loss= 0.0285, Training Accuracy= 0.992
# Step 59, Minibatch Loss= 0.0603, Training Accuracy= 0.992
# Step 60, Minibatch Loss= 0.0270, Training Accuracy= 0.988
# Step 61, Minibatch Loss= 0.0405, Training Accuracy= 0.984
# Step 62, Minibatch Loss= 0.0387, Training Accuracy= 0.988
# Step 63, Minibatch Loss= 0.1192, Training Accuracy= 0.984
# Step 64, Minibatch Loss= 0.0339, Training Accuracy= 0.996
# Step 65, Minibatch Loss= 0.0425, Training Accuracy= 0.988
# Step 66, Minibatch Loss= 0.0445, Training Accuracy= 0.984
# Step 67, Minibatch Loss= 0.0208, Training Accuracy= 0.996
# Step 68, Minibatch Loss= 0.0338, Training Accuracy= 0.988
# Step 69, Minibatch Loss= 0.0390, Training Accuracy= 0.977
# Step 70, Minibatch Loss= 0.0312, Training Accuracy= 0.992
# Step 71, Minibatch Loss= 0.0794, Training Accuracy= 0.980
# Step 72, Minibatch Loss= 0.0864, Training Accuracy= 0.973
# Step 73, Minibatch Loss= 0.0524, Training Accuracy= 0.980
# Step 74, Minibatch Loss= 0.0340, Training Accuracy= 0.992
# Step 75, Minibatch Loss= 0.0378, Training Accuracy= 0.988
# Step 76, Minibatch Loss= 0.0464, Training Accuracy= 0.980
# Step 77, Minibatch Loss= 0.0317, Training Accuracy= 0.992
# Step 78, Minibatch Loss= 0.0261, Training Accuracy= 0.996
# Step 79, Minibatch Loss= 0.0191, Training Accuracy= 0.992
# Step 80, Minibatch Loss= 0.0439, Training Accuracy= 0.984
# Step 81, Minibatch Loss= 0.0481, Training Accuracy= 0.984
# Step 82, Minibatch Loss= 0.0326, Training Accuracy= 0.992
# Step 83, Minibatch Loss= 0.0456, Training Accuracy= 0.988
# Step 84, Minibatch Loss= 0.0750, Training Accuracy= 0.969
# Step 85, Minibatch Loss= 0.0408, Training Accuracy= 0.988
# Step 86, Minibatch Loss= 0.0447, Training Accuracy= 0.984
# Step 87, Minibatch Loss= 0.0495, Training Accuracy= 0.980
# Step 88, Minibatch Loss= 0.0351, Training Accuracy= 0.992
# Step 89, Minibatch Loss= 0.0505, Training Accuracy= 0.984
# Step 90, Minibatch Loss= 0.0767, Training Accuracy= 0.977
# Step 91, Minibatch Loss= 0.0757, Training Accuracy= 0.977
# Step 92, Minibatch Loss= 0.0632, Training Accuracy= 0.988
# Step 93, Minibatch Loss= 0.0394, Training Accuracy= 0.988
# Step 94, Minibatch Loss= 0.0612, Training Accuracy= 0.973
# Step 95, Minibatch Loss= 0.0445, Training Accuracy= 0.984
# Step 96, Minibatch Loss= 0.0649, Training Accuracy= 0.984
# Step 97, Minibatch Loss= 0.0638, Training Accuracy= 0.977
# Step 98, Minibatch Loss= 0.0602, Training Accuracy= 0.984
# Step 99, Minibatch Loss= 0.0138, Training Accuracy= 0.996
# Step 100, Minibatch Loss= 0.0538, Training Accuracy= 0.980
# Step 101, Minibatch Loss= 0.0551, Training Accuracy= 0.988
# Step 102, Minibatch Loss= 0.0322, Training Accuracy= 0.988
# Step 103, Minibatch Loss= 0.0247, Training Accuracy= 0.992
# Step 104, Minibatch Loss= 0.0436, Training Accuracy= 0.988
# Step 105, Minibatch Loss= 0.0387, Training Accuracy= 0.984
# Step 106, Minibatch Loss= 0.0276, Training Accuracy= 0.992
# Step 107, Minibatch Loss= 0.0265, Training Accuracy= 0.996
# Step 108, Minibatch Loss= 0.0559, Training Accuracy= 0.984
# Step 109, Minibatch Loss= 0.0393, Training Accuracy= 0.988
# Step 110, Minibatch Loss= 0.0225, Training Accuracy= 0.992
# Step 111, Minibatch Loss= 0.0421, Training Accuracy= 0.984
# Step 112, Minibatch Loss= 0.0655, Training Accuracy= 0.977
# Step 113, Minibatch Loss= 0.0157, Training Accuracy= 0.996
# Step 114, Minibatch Loss= 0.0477, Training Accuracy= 0.984
# Step 115, Minibatch Loss= 0.0551, Training Accuracy= 0.977
# Step 116, Minibatch Loss= 0.0368, Training Accuracy= 0.984
# Step 117, Minibatch Loss= 0.0502, Training Accuracy= 0.988
# Step 118, Minibatch Loss= 0.0514, Training Accuracy= 0.984
# Step 119, Minibatch Loss= 0.0147, Training Accuracy= 0.996
# Step 120, Minibatch Loss= 0.0216, Training Accuracy= 0.992
# Step 121, Minibatch Loss= 0.0261, Training Accuracy= 0.988
# Step 122, Minibatch Loss= 0.0134, Training Accuracy= 1.000
# Step 123, Minibatch Loss= 0.0498, Training Accuracy= 0.988
# Step 124, Minibatch Loss= 0.0210, Training Accuracy= 0.992
# Step 125, Minibatch Loss= 0.0303, Training Accuracy= 0.988
# Step 126, Minibatch Loss= 0.0151, Training Accuracy= 0.996
# Step 127, Minibatch Loss= 0.0690, Training Accuracy= 0.977
# Step 128, Minibatch Loss= 0.0258, Training Accuracy= 0.992
# Step 129, Minibatch Loss= 0.0296, Training Accuracy= 0.992
# Step 130, Minibatch Loss= 0.0494, Training Accuracy= 0.992
# Step 131, Minibatch Loss= 0.0073, Training Accuracy= 1.000
# Step 132, Minibatch Loss= 0.0178, Training Accuracy= 0.996
# Step 133, Minibatch Loss= 0.0466, Training Accuracy= 0.988
# Step 134, Minibatch Loss= 0.0214, Training Accuracy= 0.992
# Step 135, Minibatch Loss= 0.0191, Training Accuracy= 0.996
# Step 136, Minibatch Loss= 0.0303, Training Accuracy= 0.988
# Step 137, Minibatch Loss= 0.0185, Training Accuracy= 0.992
# Step 138, Minibatch Loss= 0.0494, Training Accuracy= 0.988
# Step 139, Minibatch Loss= 0.0320, Training Accuracy= 0.992
# Step 140, Minibatch Loss= 0.0291, Training Accuracy= 0.992
# Step 141, Minibatch Loss= 0.0312, Training Accuracy= 0.996
# Step 142, Minibatch Loss= 0.0309, Training Accuracy= 0.988
# Step 143, Minibatch Loss= 0.0368, Training Accuracy= 0.984
# Step 144, Minibatch Loss= 0.0675, Training Accuracy= 0.977
# Step 145, Minibatch Loss= 0.0504, Training Accuracy= 0.984
# Step 146, Minibatch Loss= 0.0284, Training Accuracy= 0.992
# Step 147, Minibatch Loss= 0.0441, Training Accuracy= 0.984
# Step 148, Minibatch Loss= 0.0236, Training Accuracy= 0.992
# Step 149, Minibatch Loss= 0.0301, Training Accuracy= 0.988
# Step 150, Minibatch Loss= 0.0141, Training Accuracy= 1.000
# Step 151, Minibatch Loss= 0.0410, Training Accuracy= 0.984
# Step 152, Minibatch Loss= 0.0339, Training Accuracy= 0.984
# Step 153, Minibatch Loss= 0.0431, Training Accuracy= 0.984
# Step 154, Minibatch Loss= 0.0170, Training Accuracy= 0.996
# Step 155, Minibatch Loss= 0.0385, Training Accuracy= 0.988
# Step 156, Minibatch Loss= 0.0617, Training Accuracy= 0.977
# Step 157, Minibatch Loss= 0.0524, Training Accuracy= 0.980
# Step 158, Minibatch Loss= 0.0564, Training Accuracy= 0.988
# Step 159, Minibatch Loss= 0.0205, Training Accuracy= 0.988
# Step 160, Minibatch Loss= 0.0314, Training Accuracy= 0.988
# Step 161, Minibatch Loss= 0.0532, Training Accuracy= 0.984
# Step 162, Minibatch Loss= 0.0161, Training Accuracy= 0.996
# Step 163, Minibatch Loss= 0.0321, Training Accuracy= 0.992
# Step 164, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# total_epoch_acc 0.9871212121212121
# epoch3
# Step 0, Minibatch Loss= 0.0361, Training Accuracy= 0.988
# Step 1, Minibatch Loss= 0.0117, Training Accuracy= 0.996
# Step 2, Minibatch Loss= 0.0520, Training Accuracy= 0.992
# Step 3, Minibatch Loss= 0.0269, Training Accuracy= 0.992
# Step 4, Minibatch Loss= 0.0252, Training Accuracy= 0.992
# Step 5, Minibatch Loss= 0.0238, Training Accuracy= 0.988
# Step 6, Minibatch Loss= 0.0111, Training Accuracy= 0.996
# Step 7, Minibatch Loss= 0.0389, Training Accuracy= 0.992
# Step 8, Minibatch Loss= 0.0198, Training Accuracy= 0.992
# Step 9, Minibatch Loss= 0.0276, Training Accuracy= 0.988
# Step 10, Minibatch Loss= 0.0238, Training Accuracy= 0.992
# Step 11, Minibatch Loss= 0.0481, Training Accuracy= 0.984
# Step 12, Minibatch Loss= 0.0261, Training Accuracy= 0.992
# Step 13, Minibatch Loss= 0.0171, Training Accuracy= 0.996
# Step 14, Minibatch Loss= 0.0523, Training Accuracy= 0.980
# Step 15, Minibatch Loss= 0.0603, Training Accuracy= 0.980
# Step 16, Minibatch Loss= 0.0217, Training Accuracy= 0.996
# Step 17, Minibatch Loss= 0.0195, Training Accuracy= 0.992
# Step 18, Minibatch Loss= 0.0258, Training Accuracy= 0.988
# Step 19, Minibatch Loss= 0.0577, Training Accuracy= 0.980
# Step 20, Minibatch Loss= 0.0435, Training Accuracy= 0.984
# Step 21, Minibatch Loss= 0.0383, Training Accuracy= 0.992
# Step 22, Minibatch Loss= 0.0514, Training Accuracy= 0.980
# Step 23, Minibatch Loss= 0.0451, Training Accuracy= 0.988
# Step 24, Minibatch Loss= 0.0476, Training Accuracy= 0.984
# Step 25, Minibatch Loss= 0.0299, Training Accuracy= 0.996
# Step 26, Minibatch Loss= 0.0370, Training Accuracy= 0.992
# Step 27, Minibatch Loss= 0.0216, Training Accuracy= 0.996
# Step 28, Minibatch Loss= 0.0275, Training Accuracy= 0.996
# Step 29, Minibatch Loss= 0.1073, Training Accuracy= 0.965
# Step 30, Minibatch Loss= 0.0419, Training Accuracy= 0.984
# Step 31, Minibatch Loss= 0.0352, Training Accuracy= 0.992
# Step 32, Minibatch Loss= 0.0268, Training Accuracy= 0.992
# Step 33, Minibatch Loss= 0.0216, Training Accuracy= 0.992
# Step 34, Minibatch Loss= 0.0178, Training Accuracy= 1.000
# Step 35, Minibatch Loss= 0.0247, Training Accuracy= 0.988
# Step 36, Minibatch Loss= 0.0364, Training Accuracy= 0.996
# Step 37, Minibatch Loss= 0.0179, Training Accuracy= 0.992
# Step 38, Minibatch Loss= 0.0204, Training Accuracy= 0.992
# Step 39, Minibatch Loss= 0.0115, Training Accuracy= 1.000
# Step 40, Minibatch Loss= 0.0270, Training Accuracy= 0.988
# Step 41, Minibatch Loss= 0.0494, Training Accuracy= 0.984
# Step 42, Minibatch Loss= 0.0348, Training Accuracy= 0.984
# Step 43, Minibatch Loss= 0.0182, Training Accuracy= 0.996
# Step 44, Minibatch Loss= 0.0211, Training Accuracy= 0.988
# Step 45, Minibatch Loss= 0.0123, Training Accuracy= 0.996
# Step 46, Minibatch Loss= 0.0219, Training Accuracy= 0.996
# Step 47, Minibatch Loss= 0.0172, Training Accuracy= 0.992
# Step 48, Minibatch Loss= 0.0408, Training Accuracy= 0.988
# Step 49, Minibatch Loss= 0.0200, Training Accuracy= 0.988
# Step 50, Minibatch Loss= 0.1207, Training Accuracy= 0.965
# Step 51, Minibatch Loss= 0.0496, Training Accuracy= 0.980
# Step 52, Minibatch Loss= 0.0253, Training Accuracy= 0.992
# Step 53, Minibatch Loss= 0.0367, Training Accuracy= 0.988
# Step 54, Minibatch Loss= 0.0369, Training Accuracy= 0.988
# Step 55, Minibatch Loss= 0.0173, Training Accuracy= 0.996
# Step 56, Minibatch Loss= 0.0685, Training Accuracy= 0.973
# Step 57, Minibatch Loss= 0.0151, Training Accuracy= 0.996
# Step 58, Minibatch Loss= 0.0419, Training Accuracy= 0.988
# Step 59, Minibatch Loss= 0.0507, Training Accuracy= 0.984
# Step 60, Minibatch Loss= 0.0158, Training Accuracy= 0.996
# Step 61, Minibatch Loss= 0.0191, Training Accuracy= 1.000
# Step 62, Minibatch Loss= 0.0183, Training Accuracy= 0.992
# Step 63, Minibatch Loss= 0.0810, Training Accuracy= 0.988
# Step 64, Minibatch Loss= 0.0197, Training Accuracy= 0.996
# Step 65, Minibatch Loss= 0.0299, Training Accuracy= 0.988
# Step 66, Minibatch Loss= 0.0149, Training Accuracy= 0.996
# Step 67, Minibatch Loss= 0.0237, Training Accuracy= 0.988
# Step 68, Minibatch Loss= 0.0146, Training Accuracy= 0.996
# Step 69, Minibatch Loss= 0.0250, Training Accuracy= 0.992
# Step 70, Minibatch Loss= 0.0295, Training Accuracy= 0.996
# Step 71, Minibatch Loss= 0.0531, Training Accuracy= 0.988
# Step 72, Minibatch Loss= 0.0661, Training Accuracy= 0.980
# Step 73, Minibatch Loss= 0.0292, Training Accuracy= 0.984
# Step 74, Minibatch Loss= 0.0183, Training Accuracy= 0.996
# Step 75, Minibatch Loss= 0.0321, Training Accuracy= 0.992
# Step 76, Minibatch Loss= 0.0268, Training Accuracy= 0.996
# Step 77, Minibatch Loss= 0.0178, Training Accuracy= 0.996
# Step 78, Minibatch Loss= 0.0166, Training Accuracy= 0.992
# Step 79, Minibatch Loss= 0.0088, Training Accuracy= 1.000
# Step 80, Minibatch Loss= 0.0283, Training Accuracy= 0.984
# Step 81, Minibatch Loss= 0.0457, Training Accuracy= 0.988
# Step 82, Minibatch Loss= 0.0195, Training Accuracy= 0.992
# Step 83, Minibatch Loss= 0.0229, Training Accuracy= 0.992
# Step 84, Minibatch Loss= 0.0515, Training Accuracy= 0.980
# Step 85, Minibatch Loss= 0.0173, Training Accuracy= 0.996
# Step 86, Minibatch Loss= 0.0282, Training Accuracy= 0.988
# Step 87, Minibatch Loss= 0.0384, Training Accuracy= 0.992
# Step 88, Minibatch Loss= 0.0324, Training Accuracy= 0.992
# Step 89, Minibatch Loss= 0.0426, Training Accuracy= 0.988
# Step 90, Minibatch Loss= 0.0589, Training Accuracy= 0.977
# Step 91, Minibatch Loss= 0.0514, Training Accuracy= 0.984
# Step 92, Minibatch Loss= 0.0591, Training Accuracy= 0.988
# Step 93, Minibatch Loss= 0.0400, Training Accuracy= 0.984
# Step 94, Minibatch Loss= 0.0447, Training Accuracy= 0.988
# Step 95, Minibatch Loss= 0.0453, Training Accuracy= 0.988
# Step 96, Minibatch Loss= 0.0277, Training Accuracy= 0.988
# Step 97, Minibatch Loss= 0.0665, Training Accuracy= 0.977
# Step 98, Minibatch Loss= 0.0379, Training Accuracy= 0.992
# Step 99, Minibatch Loss= 0.0135, Training Accuracy= 0.996
# Step 100, Minibatch Loss= 0.0478, Training Accuracy= 0.977
# Step 101, Minibatch Loss= 0.0437, Training Accuracy= 0.988
# Step 102, Minibatch Loss= 0.0347, Training Accuracy= 0.992
# Step 103, Minibatch Loss= 0.0134, Training Accuracy= 1.000
# Step 104, Minibatch Loss= 0.0244, Training Accuracy= 0.992
# Step 105, Minibatch Loss= 0.0216, Training Accuracy= 0.992
# Step 106, Minibatch Loss= 0.0198, Training Accuracy= 0.996
# Step 107, Minibatch Loss= 0.0217, Training Accuracy= 0.996
# Step 108, Minibatch Loss= 0.0507, Training Accuracy= 0.984
# Step 109, Minibatch Loss= 0.0450, Training Accuracy= 0.988
# Step 110, Minibatch Loss= 0.0138, Training Accuracy= 0.996
# Step 111, Minibatch Loss= 0.0306, Training Accuracy= 0.988
# Step 112, Minibatch Loss= 0.0458, Training Accuracy= 0.977
# Step 113, Minibatch Loss= 0.0114, Training Accuracy= 1.000
# Step 114, Minibatch Loss= 0.0397, Training Accuracy= 0.988
# Step 115, Minibatch Loss= 0.0356, Training Accuracy= 0.984
# Step 116, Minibatch Loss= 0.0257, Training Accuracy= 0.992
# Step 117, Minibatch Loss= 0.0563, Training Accuracy= 0.988
# Step 118, Minibatch Loss= 0.0367, Training Accuracy= 0.988
# Step 119, Minibatch Loss= 0.0195, Training Accuracy= 0.996
# Step 120, Minibatch Loss= 0.0194, Training Accuracy= 0.992
# Step 121, Minibatch Loss= 0.0326, Training Accuracy= 0.980
# Step 122, Minibatch Loss= 0.0160, Training Accuracy= 0.996
# Step 123, Minibatch Loss= 0.0302, Training Accuracy= 0.996
# Step 124, Minibatch Loss= 0.0272, Training Accuracy= 0.996
# Step 125, Minibatch Loss= 0.0110, Training Accuracy= 1.000
# Step 126, Minibatch Loss= 0.0153, Training Accuracy= 0.996
# Step 127, Minibatch Loss= 0.0504, Training Accuracy= 0.984
# Step 128, Minibatch Loss= 0.0097, Training Accuracy= 0.996
# Step 129, Minibatch Loss= 0.0243, Training Accuracy= 0.988
# Step 130, Minibatch Loss= 0.0346, Training Accuracy= 0.992
# Step 131, Minibatch Loss= 0.0046, Training Accuracy= 1.000
# Step 132, Minibatch Loss= 0.0133, Training Accuracy= 0.992
# Step 133, Minibatch Loss= 0.0289, Training Accuracy= 0.992
# Step 134, Minibatch Loss= 0.0099, Training Accuracy= 0.996
# Step 135, Minibatch Loss= 0.0077, Training Accuracy= 1.000
# Step 136, Minibatch Loss= 0.0279, Training Accuracy= 0.988
# Step 137, Minibatch Loss= 0.0051, Training Accuracy= 1.000
# Step 138, Minibatch Loss= 0.0478, Training Accuracy= 0.984
# Step 139, Minibatch Loss= 0.0163, Training Accuracy= 0.996
# Step 140, Minibatch Loss= 0.0287, Training Accuracy= 0.992
# Step 141, Minibatch Loss= 0.0210, Training Accuracy= 0.996
# Step 142, Minibatch Loss= 0.0392, Training Accuracy= 0.984
# Step 143, Minibatch Loss= 0.0232, Training Accuracy= 0.992
# Step 144, Minibatch Loss= 0.0695, Training Accuracy= 0.973
# Step 145, Minibatch Loss= 0.0399, Training Accuracy= 0.988
# Step 146, Minibatch Loss= 0.0337, Training Accuracy= 0.992
# Step 147, Minibatch Loss= 0.0283, Training Accuracy= 0.984
# Step 148, Minibatch Loss= 0.0080, Training Accuracy= 1.000
# Step 149, Minibatch Loss= 0.0215, Training Accuracy= 0.992
# Step 150, Minibatch Loss= 0.0139, Training Accuracy= 0.996
# Step 151, Minibatch Loss= 0.0298, Training Accuracy= 0.992
# Step 152, Minibatch Loss= 0.0215, Training Accuracy= 0.992
# Step 153, Minibatch Loss= 0.0304, Training Accuracy= 0.988
# Step 154, Minibatch Loss= 0.0113, Training Accuracy= 0.996
# Step 155, Minibatch Loss= 0.0222, Training Accuracy= 0.992
# Step 156, Minibatch Loss= 0.0299, Training Accuracy= 0.988
# Step 157, Minibatch Loss= 0.0345, Training Accuracy= 0.984
# Step 158, Minibatch Loss= 0.0462, Training Accuracy= 0.980
# Step 159, Minibatch Loss= 0.0231, Training Accuracy= 0.988
# Step 160, Minibatch Loss= 0.0189, Training Accuracy= 0.992
# Step 161, Minibatch Loss= 0.0426, Training Accuracy= 0.973
# Step 162, Minibatch Loss= 0.0149, Training Accuracy= 0.992
# Step 163, Minibatch Loss= 0.0271, Training Accuracy= 0.992
# Step 164, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# total_epoch_acc 0.9902225378787879
# epoch4
# Step 0, Minibatch Loss= 0.0197, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0073, Training Accuracy= 1.000
# Step 2, Minibatch Loss= 0.0541, Training Accuracy= 0.984
# Step 3, Minibatch Loss= 0.0236, Training Accuracy= 0.992
# Step 4, Minibatch Loss= 0.0156, Training Accuracy= 0.996
# Step 5, Minibatch Loss= 0.0122, Training Accuracy= 0.996
# Step 6, Minibatch Loss= 0.0055, Training Accuracy= 1.000
# Step 7, Minibatch Loss= 0.0215, Training Accuracy= 0.996
# Step 8, Minibatch Loss= 0.0179, Training Accuracy= 0.996
# Step 9, Minibatch Loss= 0.0312, Training Accuracy= 0.988
# Step 10, Minibatch Loss= 0.0214, Training Accuracy= 0.992
# Step 11, Minibatch Loss= 0.0547, Training Accuracy= 0.984
# Step 12, Minibatch Loss= 0.0272, Training Accuracy= 0.996
# Step 13, Minibatch Loss= 0.0153, Training Accuracy= 0.996
# Step 14, Minibatch Loss= 0.0259, Training Accuracy= 0.992
# Step 15, Minibatch Loss= 0.0469, Training Accuracy= 0.977
# Step 16, Minibatch Loss= 0.0161, Training Accuracy= 0.992
# Step 17, Minibatch Loss= 0.0182, Training Accuracy= 0.996
# Step 18, Minibatch Loss= 0.0194, Training Accuracy= 0.996
# Step 19, Minibatch Loss= 0.0284, Training Accuracy= 0.988
# Step 20, Minibatch Loss= 0.0351, Training Accuracy= 0.988
# Step 21, Minibatch Loss= 0.0235, Training Accuracy= 0.992
# Step 22, Minibatch Loss= 0.0415, Training Accuracy= 0.992
# Step 23, Minibatch Loss= 0.0306, Training Accuracy= 0.992
# Step 24, Minibatch Loss= 0.0193, Training Accuracy= 1.000
# Step 25, Minibatch Loss= 0.0149, Training Accuracy= 0.996
# Step 26, Minibatch Loss= 0.0251, Training Accuracy= 0.988
# Step 27, Minibatch Loss= 0.0142, Training Accuracy= 0.996
# Step 28, Minibatch Loss= 0.0243, Training Accuracy= 0.996
# Step 29, Minibatch Loss= 0.0870, Training Accuracy= 0.973
# Step 30, Minibatch Loss= 0.0247, Training Accuracy= 0.988
# Step 31, Minibatch Loss= 0.0180, Training Accuracy= 0.992
# Step 32, Minibatch Loss= 0.0121, Training Accuracy= 0.996
# Step 33, Minibatch Loss= 0.0113, Training Accuracy= 0.996
# Step 34, Minibatch Loss= 0.0193, Training Accuracy= 0.996
# Step 35, Minibatch Loss= 0.0167, Training Accuracy= 0.992
# Step 36, Minibatch Loss= 0.0328, Training Accuracy= 0.992
# Step 37, Minibatch Loss= 0.0181, Training Accuracy= 0.996
# Step 38, Minibatch Loss= 0.0162, Training Accuracy= 0.996
# Step 39, Minibatch Loss= 0.0085, Training Accuracy= 0.996
# Step 40, Minibatch Loss= 0.0210, Training Accuracy= 0.988
# Step 41, Minibatch Loss= 0.0330, Training Accuracy= 0.988
# Step 42, Minibatch Loss= 0.0154, Training Accuracy= 0.996
# Step 43, Minibatch Loss= 0.0268, Training Accuracy= 0.992
# Step 44, Minibatch Loss= 0.0252, Training Accuracy= 0.992
# Step 45, Minibatch Loss= 0.0115, Training Accuracy= 0.996
# Step 46, Minibatch Loss= 0.0111, Training Accuracy= 0.996
# Step 47, Minibatch Loss= 0.0140, Training Accuracy= 0.992
# Step 48, Minibatch Loss= 0.0274, Training Accuracy= 0.988
# Step 49, Minibatch Loss= 0.0227, Training Accuracy= 0.988
# Step 50, Minibatch Loss= 0.0755, Training Accuracy= 0.973
# Step 51, Minibatch Loss= 0.0278, Training Accuracy= 0.988
# Step 52, Minibatch Loss= 0.0178, Training Accuracy= 0.996
# Step 53, Minibatch Loss= 0.0352, Training Accuracy= 0.992
# Step 54, Minibatch Loss= 0.0294, Training Accuracy= 0.992
# Step 55, Minibatch Loss= 0.0148, Training Accuracy= 0.992
# Step 56, Minibatch Loss= 0.0206, Training Accuracy= 0.992
# Step 57, Minibatch Loss= 0.0066, Training Accuracy= 1.000
# Step 58, Minibatch Loss= 0.0390, Training Accuracy= 0.992
# Step 59, Minibatch Loss= 0.0284, Training Accuracy= 0.996
# Step 60, Minibatch Loss= 0.0140, Training Accuracy= 0.992
# Step 61, Minibatch Loss= 0.0112, Training Accuracy= 0.996
# Step 62, Minibatch Loss= 0.0216, Training Accuracy= 0.988
# Step 63, Minibatch Loss= 0.0895, Training Accuracy= 0.988
# Step 64, Minibatch Loss= 0.0163, Training Accuracy= 0.996
# Step 65, Minibatch Loss= 0.0177, Training Accuracy= 0.996
# Step 66, Minibatch Loss= 0.0202, Training Accuracy= 0.992
# Step 67, Minibatch Loss= 0.0147, Training Accuracy= 0.992
# Step 68, Minibatch Loss= 0.0145, Training Accuracy= 0.996
# Step 69, Minibatch Loss= 0.0114, Training Accuracy= 1.000
# Step 70, Minibatch Loss= 0.0355, Training Accuracy= 0.992
# Step 71, Minibatch Loss= 0.0296, Training Accuracy= 0.992
# Step 72, Minibatch Loss= 0.0601, Training Accuracy= 0.980
# Step 73, Minibatch Loss= 0.0124, Training Accuracy= 1.000
# Step 74, Minibatch Loss= 0.0097, Training Accuracy= 0.996
# Step 75, Minibatch Loss= 0.0240, Training Accuracy= 0.992
# Step 76, Minibatch Loss= 0.0177, Training Accuracy= 0.996
# Step 77, Minibatch Loss= 0.0162, Training Accuracy= 0.992
# Step 78, Minibatch Loss= 0.0096, Training Accuracy= 1.000
# Step 79, Minibatch Loss= 0.0107, Training Accuracy= 1.000
# Step 80, Minibatch Loss= 0.0181, Training Accuracy= 0.988
# Step 81, Minibatch Loss= 0.0353, Training Accuracy= 0.992
# Step 82, Minibatch Loss= 0.0130, Training Accuracy= 0.996
# Step 83, Minibatch Loss= 0.0143, Training Accuracy= 1.000
# Step 84, Minibatch Loss= 0.0259, Training Accuracy= 0.992
# Step 85, Minibatch Loss= 0.0074, Training Accuracy= 1.000
# Step 86, Minibatch Loss= 0.0130, Training Accuracy= 0.996
# Step 87, Minibatch Loss= 0.0235, Training Accuracy= 0.988
# Step 88, Minibatch Loss= 0.0313, Training Accuracy= 0.992
# Step 89, Minibatch Loss= 0.0181, Training Accuracy= 0.992
# Step 90, Minibatch Loss= 0.0385, Training Accuracy= 0.984
# Step 91, Minibatch Loss= 0.0260, Training Accuracy= 0.988
# Step 92, Minibatch Loss= 0.0475, Training Accuracy= 0.988
# Step 93, Minibatch Loss= 0.0229, Training Accuracy= 0.996
# Step 94, Minibatch Loss= 0.0258, Training Accuracy= 0.988
# Step 95, Minibatch Loss= 0.0386, Training Accuracy= 0.984
# Step 96, Minibatch Loss= 0.0219, Training Accuracy= 0.996
# Step 97, Minibatch Loss= 0.0524, Training Accuracy= 0.984
# Step 98, Minibatch Loss= 0.0379, Training Accuracy= 0.988
# Step 99, Minibatch Loss= 0.0059, Training Accuracy= 1.000
# Step 100, Minibatch Loss= 0.0297, Training Accuracy= 0.992
# Step 101, Minibatch Loss= 0.0338, Training Accuracy= 0.992
# Step 102, Minibatch Loss= 0.0162, Training Accuracy= 0.992
# Step 103, Minibatch Loss= 0.0106, Training Accuracy= 0.996
# Step 104, Minibatch Loss= 0.0140, Training Accuracy= 0.992
# Step 105, Minibatch Loss= 0.0101, Training Accuracy= 1.000
# Step 106, Minibatch Loss= 0.0118, Training Accuracy= 1.000
# Step 107, Minibatch Loss= 0.0143, Training Accuracy= 0.996
# Step 108, Minibatch Loss= 0.0292, Training Accuracy= 0.992
# Step 109, Minibatch Loss= 0.0335, Training Accuracy= 0.992
# Step 110, Minibatch Loss= 0.0087, Training Accuracy= 1.000
# Step 111, Minibatch Loss= 0.0133, Training Accuracy= 0.992
# Step 112, Minibatch Loss= 0.0270, Training Accuracy= 0.988
# Step 113, Minibatch Loss= 0.0090, Training Accuracy= 1.000
# Step 114, Minibatch Loss= 0.0528, Training Accuracy= 0.988
# Step 115, Minibatch Loss= 0.0256, Training Accuracy= 0.992
# Step 116, Minibatch Loss= 0.0209, Training Accuracy= 0.992
# Step 117, Minibatch Loss= 0.0386, Training Accuracy= 0.992
# Step 118, Minibatch Loss= 0.0325, Training Accuracy= 0.988
# Step 119, Minibatch Loss= 0.0103, Training Accuracy= 0.996
# Step 120, Minibatch Loss= 0.0146, Training Accuracy= 0.992
# Step 121, Minibatch Loss= 0.0140, Training Accuracy= 0.996
# Step 122, Minibatch Loss= 0.0043, Training Accuracy= 1.000
# Step 123, Minibatch Loss= 0.0160, Training Accuracy= 0.996
# Step 124, Minibatch Loss= 0.0157, Training Accuracy= 0.996
# Step 125, Minibatch Loss= 0.0106, Training Accuracy= 1.000
# Step 126, Minibatch Loss= 0.0117, Training Accuracy= 0.992
# Step 127, Minibatch Loss= 0.0486, Training Accuracy= 0.984
# Step 128, Minibatch Loss= 0.0107, Training Accuracy= 0.996
# Step 129, Minibatch Loss= 0.0183, Training Accuracy= 0.996
# Step 130, Minibatch Loss= 0.0240, Training Accuracy= 0.992
# Step 131, Minibatch Loss= 0.0033, Training Accuracy= 1.000
# Step 132, Minibatch Loss= 0.0117, Training Accuracy= 1.000
# Step 133, Minibatch Loss= 0.0292, Training Accuracy= 0.984
# Step 134, Minibatch Loss= 0.0125, Training Accuracy= 0.992
# Step 135, Minibatch Loss= 0.0079, Training Accuracy= 0.996
# Step 136, Minibatch Loss= 0.0163, Training Accuracy= 1.000
# Step 137, Minibatch Loss= 0.0053, Training Accuracy= 1.000
# Step 138, Minibatch Loss= 0.0246, Training Accuracy= 0.988
# Step 139, Minibatch Loss= 0.0108, Training Accuracy= 0.996
# Step 140, Minibatch Loss= 0.0266, Training Accuracy= 0.992
# Step 141, Minibatch Loss= 0.0168, Training Accuracy= 0.996
# Step 142, Minibatch Loss= 0.0307, Training Accuracy= 0.992
# Step 143, Minibatch Loss= 0.0158, Training Accuracy= 0.996
# Step 144, Minibatch Loss= 0.0482, Training Accuracy= 0.988
# Step 145, Minibatch Loss= 0.0350, Training Accuracy= 0.988
# Step 146, Minibatch Loss= 0.0247, Training Accuracy= 0.992
# Step 147, Minibatch Loss= 0.0230, Training Accuracy= 0.988
# Step 148, Minibatch Loss= 0.0095, Training Accuracy= 1.000
# Step 149, Minibatch Loss= 0.0090, Training Accuracy= 0.996
# Step 150, Minibatch Loss= 0.0120, Training Accuracy= 1.000
# Step 151, Minibatch Loss= 0.0149, Training Accuracy= 0.992
# Step 152, Minibatch Loss= 0.0221, Training Accuracy= 0.988
# Step 153, Minibatch Loss= 0.0086, Training Accuracy= 1.000
# Step 154, Minibatch Loss= 0.0055, Training Accuracy= 1.000
# Step 155, Minibatch Loss= 0.0101, Training Accuracy= 0.996
# Step 156, Minibatch Loss= 0.0320, Training Accuracy= 0.992
# Step 157, Minibatch Loss= 0.0215, Training Accuracy= 0.996
# Step 158, Minibatch Loss= 0.0186, Training Accuracy= 0.992
# Step 159, Minibatch Loss= 0.0135, Training Accuracy= 0.996
# ...
# Step 58, Minibatch Loss= 0.0210, Training Accuracy= 0.992
# Step 59, Minibatch Loss= 0.0155, Training Accuracy= 0.996
# Step 60, Minibatch Loss= 0.0020, Training Accuracy= 1.000
# Step 61, Minibatch Loss= 0.0086, Training Accuracy= 0.996
# Step 62, Minibatch Loss= 0.0026, Training Accuracy= 1.000
# Step 63, Minibatch Loss= 0.0548, Training Accuracy= 0.996
# Step 64, Minibatch Loss= 0.0022, Training Accuracy= 1.000
# Step 65, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 66, Minibatch Loss= 0.0083, Training Accuracy= 1.000
# Step 67, Minibatch Loss= 0.0033, Training Accuracy= 1.000
# Step 68, Minibatch Loss= 0.0075, Training Accuracy= 0.996
# Step 69, Minibatch Loss= 0.0098, Training Accuracy= 0.996
# Step 70, Minibatch Loss= 0.0204, Training Accuracy= 0.996
# Step 71, Minibatch Loss= 0.0186, Training Accuracy= 0.992
# Step 72, Minibatch Loss= 0.0086, Training Accuracy= 0.996
# Step 73, Minibatch Loss= 0.0072, Training Accuracy= 1.000
# Step 74, Minibatch Loss= 0.0023, Training Accuracy= 1.000
# Step 75, Minibatch Loss= 0.0035, Training Accuracy= 1.000
# Step 76, Minibatch Loss= 0.0032, Training Accuracy= 1.000
# Step 77, Minibatch Loss= 0.0180, Training Accuracy= 0.996
# Step 78, Minibatch Loss= 0.0034, Training Accuracy= 1.000
# Step 79, Minibatch Loss= 0.0070, Training Accuracy= 0.996
# Step 80, Minibatch Loss= 0.0064, Training Accuracy= 1.000
# Step 81, Minibatch Loss= 0.0233, Training Accuracy= 0.996
# Step 82, Minibatch Loss= 0.0013, Training Accuracy= 1.000
# Step 83, Minibatch Loss= 0.0088, Training Accuracy= 0.996
# Step 84, Minibatch Loss= 0.0110, Training Accuracy= 0.996
# Step 85, Minibatch Loss= 0.0011, Training Accuracy= 1.000
# Step 86, Minibatch Loss= 0.0017, Training Accuracy= 1.000
# Step 87, Minibatch Loss= 0.0212, Training Accuracy= 0.992
# Step 88, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 89, Minibatch Loss= 0.0039, Training Accuracy= 1.000
# Step 90, Minibatch Loss= 0.0051, Training Accuracy= 1.000
# Step 91, Minibatch Loss= 0.0209, Training Accuracy= 0.996
# Step 92, Minibatch Loss= 0.0127, Training Accuracy= 0.996
# Step 93, Minibatch Loss= 0.0052, Training Accuracy= 0.996
# Step 94, Minibatch Loss= 0.0133, Training Accuracy= 0.996
# Step 95, Minibatch Loss= 0.0068, Training Accuracy= 0.996
# Step 96, Minibatch Loss= 0.0082, Training Accuracy= 0.996
# Step 97, Minibatch Loss= 0.0432, Training Accuracy= 0.988
# Step 98, Minibatch Loss= 0.0063, Training Accuracy= 1.000
# Step 99, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Step 100, Minibatch Loss= 0.0166, Training Accuracy= 0.996
# Step 101, Minibatch Loss= 0.0235, Training Accuracy= 0.996
# Step 102, Minibatch Loss= 0.0017, Training Accuracy= 1.000
# Step 103, Minibatch Loss= 0.0044, Training Accuracy= 1.000
# Step 104, Minibatch Loss= 0.0051, Training Accuracy= 1.000
# Step 105, Minibatch Loss= 0.0025, Training Accuracy= 1.000
# Step 106, Minibatch Loss= 0.0048, Training Accuracy= 1.000
# Step 107, Minibatch Loss= 0.0047, Training Accuracy= 1.000
# Step 108, Minibatch Loss= 0.0093, Training Accuracy= 0.996
# Step 109, Minibatch Loss= 0.0041, Training Accuracy= 1.000
# Step 110, Minibatch Loss= 0.0055, Training Accuracy= 1.000
# Step 111, Minibatch Loss= 0.0065, Training Accuracy= 1.000
# Step 112, Minibatch Loss= 0.0114, Training Accuracy= 0.996
# Step 113, Minibatch Loss= 0.0039, Training Accuracy= 1.000
# Step 114, Minibatch Loss= 0.0189, Training Accuracy= 0.996
# Step 115, Minibatch Loss= 0.0090, Training Accuracy= 1.000
# Step 116, Minibatch Loss= 0.0070, Training Accuracy= 1.000
# Step 117, Minibatch Loss= 0.0145, Training Accuracy= 0.996
# Step 118, Minibatch Loss= 0.0112, Training Accuracy= 0.996
# Step 119, Minibatch Loss= 0.0032, Training Accuracy= 1.000
# Step 120, Minibatch Loss= 0.0075, Training Accuracy= 0.996
# Step 121, Minibatch Loss= 0.0061, Training Accuracy= 1.000
# Step 122, Minibatch Loss= 0.0074, Training Accuracy= 0.996
# Step 123, Minibatch Loss= 0.0173, Training Accuracy= 0.992
# Step 124, Minibatch Loss= 0.0171, Training Accuracy= 0.996
# Step 125, Minibatch Loss= 0.0052, Training Accuracy= 1.000
# Step 126, Minibatch Loss= 0.0056, Training Accuracy= 1.000
# Step 127, Minibatch Loss= 0.0090, Training Accuracy= 1.000
# Step 128, Minibatch Loss= 0.0012, Training Accuracy= 1.000
# Step 129, Minibatch Loss= 0.0066, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0025, Training Accuracy= 1.000
# Step 131, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Step 132, Minibatch Loss= 0.0105, Training Accuracy= 0.996
# Step 133, Minibatch Loss= 0.0082, Training Accuracy= 0.996
# Step 134, Minibatch Loss= 0.0031, Training Accuracy= 1.000
# Step 135, Minibatch Loss= 0.0017, Training Accuracy= 1.000
# Step 136, Minibatch Loss= 0.0149, Training Accuracy= 0.988
# Step 137, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Step 138, Minibatch Loss= 0.0160, Training Accuracy= 0.996
# Step 139, Minibatch Loss= 0.0044, Training Accuracy= 1.000
# Step 140, Minibatch Loss= 0.0302, Training Accuracy= 0.992
# Step 141, Minibatch Loss= 0.0034, Training Accuracy= 1.000
# Step 142, Minibatch Loss= 0.0123, Training Accuracy= 0.996
# Step 143, Minibatch Loss= 0.0039, Training Accuracy= 1.000
# Step 144, Minibatch Loss= 0.0357, Training Accuracy= 0.984
# Step 145, Minibatch Loss= 0.0022, Training Accuracy= 1.000
# Step 146, Minibatch Loss= 0.0110, Training Accuracy= 0.992
# Step 147, Minibatch Loss= 0.0198, Training Accuracy= 0.988
# Step 148, Minibatch Loss= 0.0033, Training Accuracy= 1.000
# Step 149, Minibatch Loss= 0.0039, Training Accuracy= 1.000
# Step 150, Minibatch Loss= 0.0092, Training Accuracy= 0.992
# Step 151, Minibatch Loss= 0.0021, Training Accuracy= 1.000
# Step 152, Minibatch Loss= 0.0041, Training Accuracy= 1.000
# Step 153, Minibatch Loss= 0.0034, Training Accuracy= 1.000
# Step 154, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Step 155, Minibatch Loss= 0.0076, Training Accuracy= 0.996
# Step 156, Minibatch Loss= 0.0038, Training Accuracy= 1.000
# Step 157, Minibatch Loss= 0.0092, Training Accuracy= 1.000
# Step 158, Minibatch Loss= 0.0131, Training Accuracy= 0.996
# Step 159, Minibatch Loss= 0.0026, Training Accuracy= 1.000
# Step 160, Minibatch Loss= 0.0020, Training Accuracy= 1.000
# Step 161, Minibatch Loss= 0.0093, Training Accuracy= 0.996
# Step 162, Minibatch Loss= 0.0086, Training Accuracy= 0.996
# Step 163, Minibatch Loss= 0.0053, Training Accuracy= 0.996
# Step 164, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# total_epoch_acc 0.9975852272727272
# epoch9
# Step 0, Minibatch Loss= 0.0019, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Step 2, Minibatch Loss= 0.0087, Training Accuracy= 0.996
# Step 3, Minibatch Loss= 0.0067, Training Accuracy= 0.996
# Step 4, Minibatch Loss= 0.0012, Training Accuracy= 1.000
# Step 5, Minibatch Loss= 0.0077, Training Accuracy= 0.996
# Step 6, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Step 7, Minibatch Loss= 0.0094, Training Accuracy= 0.996
# Step 8, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Step 9, Minibatch Loss= 0.0067, Training Accuracy= 0.996
# Step 10, Minibatch Loss= 0.0025, Training Accuracy= 1.000
# Step 11, Minibatch Loss= 0.0136, Training Accuracy= 0.996
# Step 12, Minibatch Loss= 0.0031, Training Accuracy= 1.000
# Step 13, Minibatch Loss= 0.0009, Training Accuracy= 1.000
# Step 14, Minibatch Loss= 0.0063, Training Accuracy= 0.996
# Step 15, Minibatch Loss= 0.0056, Training Accuracy= 1.000
# Step 16, Minibatch Loss= 0.0022, Training Accuracy= 1.000
# Step 17, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 18, Minibatch Loss= 0.0010, Training Accuracy= 1.000
# Step 19, Minibatch Loss= 0.0147, Training Accuracy= 0.992
# Step 20, Minibatch Loss= 0.0075, Training Accuracy= 0.996
# Step 21, Minibatch Loss= 0.0030, Training Accuracy= 1.000
# Step 22, Minibatch Loss= 0.0174, Training Accuracy= 0.988
# Step 23, Minibatch Loss= 0.0126, Training Accuracy= 0.996
# Step 24, Minibatch Loss= 0.0026, Training Accuracy= 1.000
# Step 25, Minibatch Loss= 0.0030, Training Accuracy= 1.000
# Step 26, Minibatch Loss= 0.0036, Training Accuracy= 1.000
# Step 27, Minibatch Loss= 0.0082, Training Accuracy= 0.996
# Step 28, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 29, Minibatch Loss= 0.0128, Training Accuracy= 0.996
# Step 30, Minibatch Loss= 0.0043, Training Accuracy= 1.000
# Step 31, Minibatch Loss= 0.0042, Training Accuracy= 1.000
# Step 32, Minibatch Loss= 0.0034, Training Accuracy= 1.000
# Step 33, Minibatch Loss= 0.0023, Training Accuracy= 1.000
# Step 34, Minibatch Loss= 0.0036, Training Accuracy= 1.000
# Step 35, Minibatch Loss= 0.0038, Training Accuracy= 1.000
# Step 36, Minibatch Loss= 0.0022, Training Accuracy= 1.000
# Step 37, Minibatch Loss= 0.0075, Training Accuracy= 0.996
# Step 38, Minibatch Loss= 0.0038, Training Accuracy= 1.000
# Step 39, Minibatch Loss= 0.0015, Training Accuracy= 1.000
# Step 40, Minibatch Loss= 0.0038, Training Accuracy= 1.000
# Step 41, Minibatch Loss= 0.0051, Training Accuracy= 1.000
# Step 42, Minibatch Loss= 0.0023, Training Accuracy= 1.000
# Step 43, Minibatch Loss= 0.0022, Training Accuracy= 1.000
# Step 44, Minibatch Loss= 0.0183, Training Accuracy= 0.996
# Step 45, Minibatch Loss= 0.0015, Training Accuracy= 1.000
# Step 46, Minibatch Loss= 0.0056, Training Accuracy= 0.996
# Step 47, Minibatch Loss= 0.0044, Training Accuracy= 1.000
# Step 48, Minibatch Loss= 0.0052, Training Accuracy= 0.996
# Step 49, Minibatch Loss= 0.0083, Training Accuracy= 0.996
# Step 50, Minibatch Loss= 0.0161, Training Accuracy= 0.988
# Step 51, Minibatch Loss= 0.0047, Training Accuracy= 1.000
# Step 52, Minibatch Loss= 0.0034, Training Accuracy= 1.000
# Step 53, Minibatch Loss= 0.0094, Training Accuracy= 0.996
# Step 54, Minibatch Loss= 0.0099, Training Accuracy= 0.996
# Step 55, Minibatch Loss= 0.0010, Training Accuracy= 1.000
# Step 56, Minibatch Loss= 0.0045, Training Accuracy= 1.000
# Step 57, Minibatch Loss= 0.0053, Training Accuracy= 1.000
# Step 58, Minibatch Loss= 0.0280, Training Accuracy= 0.996
# Step 59, Minibatch Loss= 0.0094, Training Accuracy= 0.996
# Step 60, Minibatch Loss= 0.0012, Training Accuracy= 1.000
# Step 61, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Step 62, Minibatch Loss= 0.0036, Training Accuracy= 0.996
# Step 63, Minibatch Loss= 0.0498, Training Accuracy= 0.996
# Step 64, Minibatch Loss= 0.0065, Training Accuracy= 0.996
# Step 65, Minibatch Loss= 0.0025, Training Accuracy= 1.000
# Step 66, Minibatch Loss= 0.0016, Training Accuracy= 1.000
# Step 67, Minibatch Loss= 0.0028, Training Accuracy= 1.000
# Step 68, Minibatch Loss= 0.0027, Training Accuracy= 1.000
# Step 69, Minibatch Loss= 0.0048, Training Accuracy= 0.996
# Step 70, Minibatch Loss= 0.0069, Training Accuracy= 0.996
# Step 71, Minibatch Loss= 0.0047, Training Accuracy= 1.000
# Step 72, Minibatch Loss= 0.0066, Training Accuracy= 1.000
# Step 73, Minibatch Loss= 0.0009, Training Accuracy= 1.000
# Step 74, Minibatch Loss= 0.0038, Training Accuracy= 0.996
# Step 75, Minibatch Loss= 0.0066, Training Accuracy= 0.996
# Step 76, Minibatch Loss= 0.0163, Training Accuracy= 0.996
# Step 77, Minibatch Loss= 0.0015, Training Accuracy= 1.000
# Step 78, Minibatch Loss= 0.0016, Training Accuracy= 1.000
# Step 79, Minibatch Loss= 0.0028, Training Accuracy= 1.000
# Step 80, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Step 81, Minibatch Loss= 0.0150, Training Accuracy= 0.996
# Step 82, Minibatch Loss= 0.0042, Training Accuracy= 0.996
# Step 83, Minibatch Loss= 0.0062, Training Accuracy= 0.996
# Step 84, Minibatch Loss= 0.0066, Training Accuracy= 0.996
# Step 85, Minibatch Loss= 0.0016, Training Accuracy= 1.000
# Step 86, Minibatch Loss= 0.0042, Training Accuracy= 0.996
# Step 87, Minibatch Loss= 0.0034, Training Accuracy= 0.996
# Step 88, Minibatch Loss= 0.0101, Training Accuracy= 0.996
# Step 89, Minibatch Loss= 0.0068, Training Accuracy= 0.996
# Step 90, Minibatch Loss= 0.0118, Training Accuracy= 0.996
# Step 91, Minibatch Loss= 0.0037, Training Accuracy= 1.000
# Step 92, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 93, Minibatch Loss= 0.0017, Training Accuracy= 1.000
# Step 94, Minibatch Loss= 0.0044, Training Accuracy= 1.000
# Step 95, Minibatch Loss= 0.0135, Training Accuracy= 0.996
# Step 96, Minibatch Loss= 0.0040, Training Accuracy= 1.000
# Step 97, Minibatch Loss= 0.0360, Training Accuracy= 0.988
# Step 98, Minibatch Loss= 0.0075, Training Accuracy= 0.996
# Step 99, Minibatch Loss= 0.0017, Training Accuracy= 1.000
# Step 100, Minibatch Loss= 0.0074, Training Accuracy= 0.996
# Step 101, Minibatch Loss= 0.0221, Training Accuracy= 0.996
# Step 102, Minibatch Loss= 0.0059, Training Accuracy= 0.996
# Step 103, Minibatch Loss= 0.0013, Training Accuracy= 1.000
# Step 104, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 105, Minibatch Loss= 0.0017, Training Accuracy= 1.000
# Step 106, Minibatch Loss= 0.0026, Training Accuracy= 1.000
# Step 107, Minibatch Loss= 0.0068, Training Accuracy= 1.000
# Step 108, Minibatch Loss= 0.0237, Training Accuracy= 0.996
# Step 109, Minibatch Loss= 0.0052, Training Accuracy= 1.000
# Step 110, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 111, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 112, Minibatch Loss= 0.0030, Training Accuracy= 1.000
# Step 113, Minibatch Loss= 0.0031, Training Accuracy= 1.000
# Step 114, Minibatch Loss= 0.0166, Training Accuracy= 0.996
# Step 115, Minibatch Loss= 0.0018, Training Accuracy= 1.000
# Step 116, Minibatch Loss= 0.0074, Training Accuracy= 0.996
# Step 117, Minibatch Loss= 0.0054, Training Accuracy= 1.000
# Step 118, Minibatch Loss= 0.0104, Training Accuracy= 1.000
# Step 119, Minibatch Loss= 0.0027, Training Accuracy= 1.000
# Step 120, Minibatch Loss= 0.0020, Training Accuracy= 1.000
# Step 121, Minibatch Loss= 0.0041, Training Accuracy= 1.000
# Step 122, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Step 123, Minibatch Loss= 0.0011, Training Accuracy= 1.000
# Step 124, Minibatch Loss= 0.0031, Training Accuracy= 1.000
# Step 125, Minibatch Loss= 0.0039, Training Accuracy= 1.000
# Step 126, Minibatch Loss= 0.0016, Training Accuracy= 1.000
# Step 127, Minibatch Loss= 0.0056, Training Accuracy= 1.000
# Step 128, Minibatch Loss= 0.0015, Training Accuracy= 1.000
# Step 129, Minibatch Loss= 0.0013, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0016, Training Accuracy= 1.000
# Step 131, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Step 132, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Step 133, Minibatch Loss= 0.0049, Training Accuracy= 1.000
# Step 134, Minibatch Loss= 0.0020, Training Accuracy= 1.000
# Step 135, Minibatch Loss= 0.0010, Training Accuracy= 1.000
# Step 136, Minibatch Loss= 0.0038, Training Accuracy= 1.000
# Step 137, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Step 138, Minibatch Loss= 0.0054, Training Accuracy= 1.000
# Step 139, Minibatch Loss= 0.0021, Training Accuracy= 1.000
# Step 140, Minibatch Loss= 0.0140, Training Accuracy= 0.996
# Step 141, Minibatch Loss= 0.0020, Training Accuracy= 1.000
# Step 142, Minibatch Loss= 0.0095, Training Accuracy= 0.992
# Step 143, Minibatch Loss= 0.0039, Training Accuracy= 1.000
# Step 144, Minibatch Loss= 0.0287, Training Accuracy= 0.988
# Step 145, Minibatch Loss= 0.0030, Training Accuracy= 1.000
# Step 146, Minibatch Loss= 0.0063, Training Accuracy= 0.996
# Step 147, Minibatch Loss= 0.0043, Training Accuracy= 1.000
# Step 148, Minibatch Loss= 0.0019, Training Accuracy= 1.000
# Step 149, Minibatch Loss= 0.0019, Training Accuracy= 1.000
# Step 150, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Step 151, Minibatch Loss= 0.0041, Training Accuracy= 1.000
# Step 152, Minibatch Loss= 0.0039, Training Accuracy= 1.000
# Step 153, Minibatch Loss= 0.0043, Training Accuracy= 1.000
# Step 154, Minibatch Loss= 0.0010, Training Accuracy= 1.000
# Step 155, Minibatch Loss= 0.0039, Training Accuracy= 1.000
# Step 156, Minibatch Loss= 0.0175, Training Accuracy= 0.992
# Step 157, Minibatch Loss= 0.0086, Training Accuracy= 0.996
# Step 158, Minibatch Loss= 0.0019, Training Accuracy= 1.000
# Step 159, Minibatch Loss= 0.0019, Training Accuracy= 1.000
# Step 160, Minibatch Loss= 0.0038, Training Accuracy= 0.996
# Step 161, Minibatch Loss= 0.0110, Training Accuracy= 0.992
# Step 162, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Step 163, Minibatch Loss= 0.0015, Training Accuracy= 1.000
# Step 164, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# total_epoch_acc 0.9983664772727273

# %%
from pandas import DataFrame
session =tf.Session()
saver.restore(session ,save_path)
test_array = np.zeros((28000,1))


for i in range(0,test_steps+1):
    start = i*batch_size
    end = (i+1)*batch_size
    batch_x  =  read_test_data(start ,end)
    test_output =session.run([out] ,feed_dict = {X :batch_x , keep_prob :1.0})
    test_soft = tf.convert_to_tensor(test_output[0])
    test_soft =tf.argmax(tf.nn.softmax(test_soft) , axis = 1)
    res = session.run(test_soft)
    test_array[start:end,:] =  res.reshape([res.shape[0] , 1])
    print(test_array[start,:])
    data = batch_x[0,:,:,:] * 255
    data = (data.reshape((28,28))).astype('uint8')
    img = Image.fromarray(data)
    img.save( 'images/'+str(i)+'.jpeg')


image_id = np.arange(1,28001)
image_id.reshape((28000,1))
csv_file_array = np.zeros((28000,2) , dtype=int)
csv_file_array[:,0] = image_id
csv_file_array[:,1] = test_array.reshape((28000))
df = DataFrame(csv_file_array, columns= ['ImageId', 'Label'])
export_csv = df.to_csv (r'sample_submission.csv', index = False, header=True)
# Out:
# [2.]
# [5.]
# [8.]
# [1.]
# [2.]
# [1.]
# [0.]
# [9.]
# [2.]
# [4.]
# [4.]
# [1.]
# [5.]
# [3.]
# [9.]
# [1.]
# [5.]
# [8.]
# [9.]
# [1.]
# [9.]
# [3.]
# [9.]
# [0.]
# [8.]
# [4.]
# [7.]
# [9.]
# [9.]
# [5.]
# [5.]
# [4.]
# [8.]
# [0.]
# [6.]
# [0.]
# [0.]
# [5.]
# [4.]
# [5.]
# [6.]
# [3.]
# [1.]
# [8.]
# [3.]
# [0.]
# [3.]
# [6.]
# [9.]
# [1.]
# [0.]
# [6.]
# [8.]
# [6.]
# [4.]
# [7.]
# [0.]
# [2.]
# [0.]
# [4.]
# [7.]
# [4.]
# [4.]
# [3.]
# [5.]
# [9.]
# [0.]
# [8.]
# [2.]
# [9.]
# [0.]
# [6.]
# [7.]
# [1.]
# [2.]
# [1.]
# [4.]
# [4.]
# [0.]
# [9.]
# [2.]
# [2.]
# [1.]
# [4.]
# [1.]
# [1.]
# [5.]
# [7.]
# [6.]
# [9.]
# [5.]
# [8.]
# [9.]
# [0.]
# [5.]
# [3.]
# [0.]
# [1.]
# [0.]
# [6.]
# [4.]
# [2.]
# [3.]
# [1.]
# [1.]
# [9.]
# [7.]
# [0.]
# [7.]
# [1.]

# %%
session =tf.Session()
saver.restore(session ,save_path)
for j in range(0,num_epoch):
        total_epoch_acc = 0
        print("epoch" + str(j))
        for i in range(0,steps+1):
            start = i*batch_size
            end = (i+1)*batch_size
            batch_x ,batch_y =  read_training_data(start ,end)
            session.run(train,feed_dict = {X :batch_x ,Y:batch_y , keep_prob : dropout})
            loss , acc =session.run([cost,accuracy] ,feed_dict = {X :batch_x ,Y:batch_y , keep_prob :1.0})
            total_epoch_acc += acc
            print("Step " + str(i) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))
        print("total_epoch_acc " + str(total_epoch_acc / (steps+1)) )
        saver.save(sess, save_path)
# Out:
# epoch0
# Step 0, Minibatch Loss= 0.0028, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0009, Training Accuracy= 1.000
# Step 2, Minibatch Loss= 0.0036, Training Accuracy= 1.000
# Step 3, Minibatch Loss= 0.0231, Training Accuracy= 0.992
# Step 4, Minibatch Loss= 0.0025, Training Accuracy= 1.000
# Step 5, Minibatch Loss= 0.0058, Training Accuracy= 0.996
# Step 6, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Step 7, Minibatch Loss= 0.0044, Training Accuracy= 1.000
# Step 8, Minibatch Loss= 0.0023, Training Accuracy= 1.000
# Step 9, Minibatch Loss= 0.0127, Training Accuracy= 0.992
# Step 10, Minibatch Loss= 0.0036, Training Accuracy= 1.000
# Step 11, Minibatch Loss= 0.0058, Training Accuracy= 1.000
# Step 12, Minibatch Loss= 0.0026, Training Accuracy= 1.000
# Step 13, Minibatch Loss= 0.0016, Training Accuracy= 1.000
# Step 14, Minibatch Loss= 0.0106, Training Accuracy= 0.992
# Step 15, Minibatch Loss= 0.0111, Training Accuracy= 0.992
# Step 16, Minibatch Loss= 0.0018, Training Accuracy= 1.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-1c1f8123df5d> in <module>
#       8             end = (i+1)*batch_size
#       9             batch_x ,batch_y =  read_training_data(start ,end)
# ---> 10             session.run(train,feed_dict = {X :batch_x ,Y:batch_y , keep_prob : dropout})
#      11             loss , acc =session.run([cost,accuracy] ,feed_dict = {X :batch_x ,Y:batch_y , keep_prob :1.0})
#      12             total_epoch_acc += acc
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
